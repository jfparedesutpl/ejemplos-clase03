# %%
import pandas as pd

# %%
# !pip install faker
# Out:
# Collecting faker
#   Using cached Faker-24.11.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /home/reroes/entornos/envpy310-ia-c3/lib/python3.10/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/reroes/entornos/envpy310-ia-c3/lib/python3.10/site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Using cached Faker-24.11.0-py3-none-any.whl (1.8 MB)
# Installing collected packages: faker
# Successfully installed faker-24.11.0

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,51):
    lista.append({'nombre': fake.name()})

# %%
lista
# Out:
# [{'nombre': 'Samuel Pope'},
#  {'nombre': 'Jason Cooper'},
#  {'nombre': 'Jonathan Lee'},
#  {'nombre': 'David Johnson'},
#  {'nombre': 'Matthew Martinez'},
#  {'nombre': 'Anne Bates'},
#  {'nombre': 'Howard Miller'},
#  {'nombre': 'Tiffany Johnson'},
#  {'nombre': 'David Smith'},
#  {'nombre': 'Ms. Dawn Knapp DDS'},
#  {'nombre': 'Daniel Burke'},
#  {'nombre': 'David Haas'},
#  {'nombre': 'Michael Harper'},
#  {'nombre': 'Tonya Wheeler'},
#  {'nombre': 'Valerie Ramirez'},
#  {'nombre': 'Heather Jones'},
#  {'nombre': 'Melissa Ramirez'},
#  {'nombre': 'Michael White'},
#  {'nombre': 'Mike Johnson'},
#  {'nombre': 'Katelyn Shelton'},
#  {'nombre': 'Stephanie Murphy'},
#  {'nombre': 'Jennifer Mcconnell'},
#  {'nombre': 'Holly Pearson'},
#  {'nombre': 'Cassandra Thomas'},
#  {'nombre': 'Abigail Martinez'},
#  {'nombre': 'Brandon Esparza'},
#  {'nombre': 'Bradley Howard'},
#  {'nombre': 'Isaac Haas'},
#  {'nombre': 'Savannah Williams'},
#  {'nombre': 'Susan Osborne'},
#  {'nombre': 'Chelsea Goodwin'},
#  {'nombre': 'Eric Koch'},
#  {'nombre': 'Gina West'},
#  {'nombre': 'Julia Collier'},
#  {'nombre': 'James Walker'},
#  {'nombre': 'Steven Williamson'},
#  {'nombre': 'Sally Turner'},
#  {'nombre': 'James Anderson'},
#  {'nombre': 'Christopher Mendoza'},
#  {'nombre': 'Timothy Hogan'},
#  {'nombre': 'Dawn Marks'},
#  {'nombre': 'Tonya Elliott'},
#  {'nombre': 'Eric Smith'},
#  {'nombre': 'David Krause MD'},
#  {'nombre': 'Shelby Mcdonald'},
#  {'nombre': 'Brian Swanson MD'},
#  {'nombre': 'Megan Hansen'},
#  {'nombre': 'Alexander Caldwell'},
#  {'nombre': 'Crystal Williams'},
#  {'nombre': 'Stephanie Hicks'},
#  {'nombre': 'Maria Johnson'}]

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                  nombre
# 0           Samuel Pope
# 1          Jason Cooper
# 2          Jonathan Lee
# 3         David Johnson
# 4      Matthew Martinez
# 5            Anne Bates
# 6         Howard Miller
# 7       Tiffany Johnson
# 8           David Smith
# 9    Ms. Dawn Knapp DDS
# 10         Daniel Burke
# 11           David Haas
# 12       Michael Harper
# 13        Tonya Wheeler
# 14      Valerie Ramirez
# 15        Heather Jones
# 16      Melissa Ramirez
# 17        Michael White
# 18         Mike Johnson
# 19      Katelyn Shelton
# 20     Stephanie Murphy
# 21   Jennifer Mcconnell
# 22        Holly Pearson
# 23     Cassandra Thomas
# 24     Abigail Martinez
# 25      Brandon Esparza
# 26       Bradley Howard
# 27           Isaac Haas
# 28    Savannah Williams
# 29        Susan Osborne
# 30      Chelsea Goodwin
# 31            Eric Koch
# 32            Gina West
# 33        Julia Collier
# 34         James Walker
# 35    Steven Williamson
# 36         Sally Turner
# 37       James Anderson
# 38  Christopher Mendoza
# 39        Timothy Hogan
# 40           Dawn Marks
# 41        Tonya Elliott
# 42           Eric Smith
# 43      David Krause MD
# 44      Shelby Mcdonald
# 45     Brian Swanson MD
# 46         Megan Hansen
# 47   Alexander Caldwell
# 48     Crystal Williams
# 49      Stephanie Hicks
# 50        Maria Johnson

# %%
data.to_csv("misdata.csv", index=False)
